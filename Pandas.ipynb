# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(['raj', 'jag', 'ref'])

# %%
df
# Out:
#      0
# 0  raj
# 1  jag
# 2  ref

# %%
df = pd.DataFrame(['raj', 'jag', 'ref'],['raj', 'jag', 'ref'] )
df
# Out:
#        0
# raj  raj
# jag  jag
# ref  ref

# %%
df = pd.DataFrame([['raj', 'jag', 'ref'],['apple', 'bat', 'camel'], ['raj', 'jag', 'ref']] )
df
# Out:
#        0    1      2
# 0    raj  jag    ref
# 1  apple  bat  camel
# 2    raj  jag    ref

# %%
data = {'Category':['Array', 'Stack', 'Queue'],
        'Marks':[20, 21, 19]}
df = pd.DataFrame(data) 
df
# Out:
#   Category  Marks
# 0    Array     20
# 1    Stack     21
# 2    Queue     19

# %%
df.transpose()
# Out:
#               0      1      2
# Category  Array  Stack  Queue
# Marks        20     21     19

# %%
data = {'Category':['Array', 'Stack', 'Queue'],
        'Marks':[20, 21, 19]}
df = pd.DataFrame(data, index = ['first', 'second', 'third']) 
df
# Out:
#        Category  Marks
# first     Array     20
# second    Stack     21
# third     Queue     19

# %%
data = [['DS', 'Linked_list', 10], ['DS', 'Stack', 9], ['DS', 'Queue', 7],
        ['Algo', 'Greedy', 8], ['Algo', 'DP', 6], ['Algo', 'BackTrack', 5], ]
df = pd.DataFrame(data, columns = ['Sub', 'topic', 'ques'])
df
# Out:
#     Sub        topic  ques
# 0    DS  Linked_list    10
# 1    DS        Stack     9
# 2    DS        Queue     7
# 3  Algo       Greedy     8
# 4  Algo           DP     6
# 5  Algo    BackTrack     5

# %%
data = [('Peter', 18, 7),
        ('Riff', 15, 6),
        ('John', 17, 8),
        ('Michel', 18, 7),
        ('Sheli', 17, 5) ]
df = pd.DataFrame(data, index = ['fir', 'sec', 'thir', 'four', 'five'], columns = ['name', 'age', 'ques'])
df
# Out:
#         name  age  ques
# fir    Peter   18     7
# sec     Riff   15     6
# thir    John   17     8
# four  Michel   18     7
# five   Sheli   17     5

# %%
df = pd.read_csv(r"C:\Users\Shivam\Desktop\Python\bmw csv.csv")
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic  67068.0   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic  14827.0   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic      NaN   Diesel  160  51.4
# 3       1 Series  2017  12750          NaN  26676.0   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic  39554.0   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic  40818.0   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic  42947.0   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual  25468.0   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic  45000.0   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic  59432.0   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
df.model
# Out:
# 0         5 Series
# 1         6 Series
# 2         5 Series
# 3         1 Series
# 4         7 Series
#            ...
# 10776           X3
# 10777     5 Series
# 10778     3 Series
# 10779     1 Series
# 10780           X1
# Name: model, Length: 10781, dtype: object

# %%
df2 = df[df['year'] == 2014]
df2.head(5)
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0    5 Series  2014  11200    Automatic  67068.0   Diesel  125  57.6
# 4    7 Series  2014  14500    Automatic  39554.0   Diesel  160  50.4
# 19   4 Series  2014  14000    Automatic  47348.0   Diesel  125  60.1
# 51   5 Series  2014  11000    Automatic  84816.0   Diesel   30  62.8
# 54   3 Series  2014  14000       Manual  32139.0   Petrol  205  43.5
#
#     engineSize
# 0          2.0
# 4          NaN
# 19         2.0
# 51         2.0
# 54         2.0

# %%
df2 = df[df['model'] == 5 Series]
df2.head(5)
# Out:
#   Cell In [57], line 1
#     df2 = df[df['model'] == 5 Series]
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10775 non-null  object
#  4   mileage       10775 non-null  float64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10774 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 758.2+ KB

# %%
df2 = df.loc[df['year'] == 2014]
df2
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic  67068.0   Diesel  125  57.6
# 4       7 Series  2014  14500    Automatic  39554.0   Diesel  160  50.4
# 19      4 Series  2014  14000    Automatic  47348.0   Diesel  125  60.1
# 51      5 Series  2014  11000    Automatic  84816.0   Diesel   30  62.8
# 54      3 Series  2014  14000       Manual  32139.0   Petrol  205  43.5
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10733   2 Series  2014  10990       Manual  57000.0   Diesel  125  58.9
# 10737   3 Series  2014  17499    Automatic  48100.0   Diesel  160  52.3
# 10750   2 Series  2014  15995    Automatic  58000.0   Petrol  265  37.2
# 10758         X3  2014  14400    Automatic  43307.0   Diesel  145  54.3
# 10779   1 Series  2014   9930    Automatic  45000.0   Diesel   30  64.2
#
#        engineSize
# 0             2.0
# 4             NaN
# 19            2.0
# 51            2.0
# ...

# %%
options = [2014, 2017]
df2 = df[df['year'].isin(options)]
df2
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic  67068.0   Diesel  125  57.6
# 3       1 Series  2017  12750          NaN  26676.0   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic  39554.0   Diesel  160  50.4
# 6       5 Series  2017  16000    Automatic  38538.0   Diesel  125  60.1
# 8       4 Series  2017  14250       Manual  42668.0   Diesel   30  62.8
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10772   1 Series  2017  10200       Manual  41435.0   Diesel    0  83.1
# 10773         X1  2017  15900    Automatic  60372.0   Diesel  125  57.6
# 10778   3 Series  2017  13100       Manual  25468.0   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic  45000.0   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic  59432.0   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 3             1.5
# 4             NaN
# 6             2.0
# ...

# %%
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(dict)
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df['Second Score'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# Name: Second Score, dtype: bool

# %%
df.isna()
# isnull( = same
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
df.notnull()
# isnull( = same
# Out:
#    First Score  Second Score  Third Score
# 0         True          True        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %%
df.fillna(1000)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0       1000.0
# 1         90.0          45.0         40.0
# 2       1000.0          56.0         80.0
# 3         95.0        1000.0         98.0

# %%
df.replace(to_replace = np.nan, value = 'hey')
# Out:
#   First Score Second Score Third Score
# 0       100.0         30.0         hey
# 1        90.0         45.0        40.0
# 2         hey         56.0        80.0
# 3        95.0          hey        98.0

# %%
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df.replace({'First Score': 100, 'Second Score' : 30}, 'hey')
# Out:
#   First Score Second Score  Third Score
# 0         hey          hey          NaN
# 1        90.0         45.0         40.0
# 2         NaN         56.0         80.0
# 3        95.0          NaN         98.0

# %%
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
# interpolate - to estimate unkwown datapoints by using know points
df.interpolate(method ='linear', limit_direction ='forward')
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         92.5          56.0         80.0
# 3         95.0          56.0         98.0

# %%
dict1 = {"fourth score" : [88, 47,100]}
data = pd.DataFrame(dict1)
new = pd.concat([df, data], axis = 1)
new
# Out:
#    First Score  Second Score  Third Score  fourth score
# 0        100.0          30.0          NaN          88.0
# 1         90.0          45.0         40.0          47.0
# 2          NaN          56.0         80.0         100.0
# 3         95.0           NaN         98.0           NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [31], line 3
#       1 dict1 = {"fourth score" : [88, 47,100]}
#       2 data = pd.DataFrame(dict1)
# ----> 3 new = pd.merge([df, data])
#       4 new
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
df = pd.read_csv(r"C:\Users\Shivam\Desktop\Python\bmw csv.csv")
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic  67068.0   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic  14827.0   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic      NaN   Diesel  160  51.4
# 3       1 Series  2017  12750          NaN  26676.0   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic  39554.0   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic  40818.0   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic  42947.0   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual  25468.0   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic  45000.0   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic  59432.0   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
df2 = list(df.groupby('model'))

# %%
df2
# Out:
# [(' 1 Series',
#              model  year  price transmission  mileage fuelType  tax   mpg  \
#   3       1 Series  2017  12750          NaN  26676.0   Diesel  145  72.4
#   11      1 Series  2017  11800       Manual  29840.0   Diesel   20  68.9
#   18      1 Series  2017  15500    Automatic  22812.0   Diesel   20  68.9
#   20      1 Series  2015   9700    Automatic  75124.0   Diesel   20  70.6
#   23      1 Series  2016   9400       Manual  44498.0   Diesel    0  83.1
#   ...          ...   ...    ...          ...      ...      ...  ...   ...
#   10763   1 Series  2016   8500       Manual  68810.0   Diesel    0  83.1
#   10764   1 Series  2016   9100       Manual  54596.0   Diesel    0  83.1
#   10766   1 Series  2016   8700       Manual  54987.0   Diesel    0  83.1
#   10772   1 Series  2017  10200       Manual  41435.0   Diesel    0  83.1
#   10779   1 Series  2014   9930    Automatic  45000.0   Diesel   30  64.2
#
#          engineSize
#   3             1.5
#   11            2.0
# ...

# %%
df2 = df.rename(index = {0 : "Model"})
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic  67068.0   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic  14827.0   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic      NaN   Diesel  160  51.4
# 3       1 Series  2017  12750          NaN  26676.0   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic  39554.0   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic  40818.0   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic  42947.0   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual  25468.0   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic  45000.0   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic  59432.0   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
df2 = df.rename(columns = {'model' : "Model"})
df2
# Out:
#            Model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic  67068.0   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic  14827.0   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic      NaN   Diesel  160  51.4
# 3       1 Series  2017  12750          NaN  26676.0   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic  39554.0   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic  40818.0   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic  42947.0   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual  25468.0   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic  45000.0   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic  59432.0   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
df.columns = ['Model', 'Year', 'Pr', 'Trans', 'Mil', 'FT', 'Tax', 'MPG', 'Eng']
df
# Out:
#            Model  Year     Pr      Trans      Mil      FT  Tax   MPG  Eng
# 0       5 Series  2014  11200  Automatic  67068.0  Diesel  125  57.6  2.0
# 1       6 Series  2018  27000  Automatic  14827.0  Petrol  145  42.8  2.0
# 2       5 Series  2016  16000  Automatic      NaN  Diesel  160  51.4  3.0
# 3       1 Series  2017  12750        NaN  26676.0  Diesel  145  72.4  1.5
# 4       7 Series  2014  14500  Automatic  39554.0  Diesel  160  50.4  NaN
# ...          ...   ...    ...        ...      ...     ...  ...   ...  ...
# 10776         X3  2016  19000  Automatic  40818.0  Diesel  150  54.3  2.0
# 10777   5 Series  2016  14600  Automatic  42947.0  Diesel  125  60.1  2.0
# 10778   3 Series  2017  13100     Manual  25468.0  Petrol  200  42.8  2.0
# 10779   1 Series  2014   9930  Automatic  45000.0  Diesel   30  64.2  2.0
# 10780         X1  2017  15981  Automatic  59432.0  Diesel  125  57.6  2.0
#
# [10781 rows x 9 columns]

# %%
df2 = df.sort_values(by = 'Year', ascending = False)
df2
# Out:
#           Model  Year     Pr      Trans      Mil      FT  Tax   MPG  Eng
# 4376         X2  2020  34360  Semi-Auto    835.0  Petrol  145  38.7  2.0
# 5391   2 Series  2020  26000  Semi-Auto   1501.0  Petrol  145  42.2  1.5
# 3274   5 Series  2020  28990  Semi-Auto    103.0  Petrol  145  50.4  2.0
# 7898   3 Series  2020  37250  Automatic    101.0  Diesel  145  47.9  3.0
# 6965         X3  2020  52991  Semi-Auto   4360.0  Hybrid  135   5.5  2.0
# ...         ...   ...    ...        ...      ...     ...  ...   ...  ...
# 9555         Z3  1999   3995     Manual  74282.0  Petrol  245  35.3  1.9
# 9744   3 Series  1999   1200  Automatic  82000.0  Petrol  245  31.0  2.8
# 9842         Z3  1998   3950     Manual  56500.0  Petrol  270  35.3  1.9
# 9841         Z3  1997   3950     Manual  49000.0  Petrol  270  35.3  1.9
# 9625   5 Series  1996   5995  Automatic  36000.0  Petrol  270  26.4  2.8
#
# [10781 rows x 9 columns]

# %%
df.aggregate(['sum','min'])
# Out:
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_23852\4203260843.py:1: FutureWarning: ['Trans'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.aggregate(['sum','min'])
#                                                  Model      Year         Pr  \
# sum   5 Series 6 Series 5 Series 1 Series 7 Series ...  21746128  245088881
# min                                           1 Series      1996       1200
#
#              Mil                                                 FT      Tax  \
# sum  274644814.0  DieselPetrolDieselDieselDieselDieselDieselPetr...  1419880
# min          1.0                                             Diesel        0
#
#           MPG      Eng
# sum  608038.0  23356.7
# min       5.5      0.0

# %%
df.aggregate({
    'Year' : ['sum', 'min'],
    'Mil': ['max', 'sum']
})
# Out:
#            Year          Mil
# sum  21746128.0  274644814.0
# min      1996.0          NaN
# max         NaN     214000.0

# %%
df[0:10]
# Out:
#        Model  Year     Pr      Trans      Mil      FT  Tax   MPG  Eng
# 0   5 Series  2014  11200  Automatic  67068.0  Diesel  125  57.6  2.0
# 1   6 Series  2018  27000  Automatic  14827.0  Petrol  145  42.8  2.0
# 2   5 Series  2016  16000  Automatic      NaN  Diesel  160  51.4  3.0
# 3   1 Series  2017  12750        NaN  26676.0  Diesel  145  72.4  1.5
# 4   7 Series  2014  14500  Automatic  39554.0  Diesel  160  50.4  NaN
# 5   5 Series  2016  14900  Automatic      NaN  Diesel  125  60.1  2.0
# 6   5 Series  2017  16000  Automatic  38538.0  Diesel  125  60.1  2.0
# 7   2 Series  2018  16250        NaN  10401.0  Petrol  145  52.3  1.5
# 8   4 Series  2017  14250     Manual  42668.0  Diesel   30  62.8  2.0
# 9   5 Series  2016  14250  Automatic  36099.0  Diesel   20  68.9  2.0

# %%
df['add'] = df.apply(lambda x : (df['Trans'] == np.nan) ? (0) : ("values"))
# Out:
#   Cell In [73], line 1
#     df['add'] = df.apply(lambda x : (df['Trans'] == np.nan) ? (0) : ("values"))
#                                                             ^
# SyntaxError: invalid syntax

# %%
df['Year'].plot.hist(bins = 20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# df['Year'].plot.line()
# df['Year'].plot.scatter()
# df['Year'].plot.box()
# df['Year'].plot.hist()

# %%
 df.plot.scatter(x = 'Year', y ='Mil')
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Mil'>

# %%
df.drop_duplicates()
# Out:
#            Model  Year     Pr      Trans      Mil      FT  Tax   MPG  Eng
# 0       5 Series  2014  11200  Automatic  67068.0  Diesel  125  57.6  2.0
# 1       6 Series  2018  27000  Automatic  14827.0  Petrol  145  42.8  2.0
# 2       5 Series  2016  16000  Automatic      NaN  Diesel  160  51.4  3.0
# 3       1 Series  2017  12750        NaN  26676.0  Diesel  145  72.4  1.5
# 4       7 Series  2014  14500  Automatic  39554.0  Diesel  160  50.4  NaN
# ...          ...   ...    ...        ...      ...     ...  ...   ...  ...
# 10776         X3  2016  19000  Automatic  40818.0  Diesel  150  54.3  2.0
# 10777   5 Series  2016  14600  Automatic  42947.0  Diesel  125  60.1  2.0
# 10778   3 Series  2017  13100     Manual  25468.0  Petrol  200  42.8  2.0
# 10779   1 Series  2014   9930  Automatic  45000.0  Diesel   30  64.2  2.0
# 10780         X1  2017  15981  Automatic  59432.0  Diesel  125  57.6  2.0
#
# [10664 rows x 9 columns]

# %%
df
# Out:
#            Model  Year     Pr      Trans      Mil      FT  Tax   MPG  Eng
# 0       5 Series  2014  11200  Automatic  67068.0  Diesel  125  57.6  2.0
# 1       6 Series  2018  27000  Automatic  14827.0  Petrol  145  42.8  2.0
# 2       5 Series  2016  16000  Automatic      NaN  Diesel  160  51.4  3.0
# 3       1 Series  2017  12750        NaN  26676.0  Diesel  145  72.4  1.5
# 4       7 Series  2014  14500  Automatic  39554.0  Diesel  160  50.4  NaN
# ...          ...   ...    ...        ...      ...     ...  ...   ...  ...
# 10776         X3  2016  19000  Automatic  40818.0  Diesel  150  54.3  2.0
# 10777   5 Series  2016  14600  Automatic  42947.0  Diesel  125  60.1  2.0
# 10778   3 Series  2017  13100     Manual  25468.0  Petrol  200  42.8  2.0
# 10779   1 Series  2014   9930  Automatic  45000.0  Diesel   30  64.2  2.0
# 10780         X1  2017  15981  Automatic  59432.0  Diesel  125  57.6  2.0
#
# [10781 rows x 9 columns]

# %%
# table = df.pivot(columns = 'Model', index = 'Yera', values = 'Trans' )
# or, pd.pivot_table(df, values = 'Value', index=['Country','Year'], columns = 'Indicator').reset_index()

# %%
print(df['Year'].corr(df['Pr']))
# Out:
# 0.6237560791328913

# %%
df.corr()
# Out:
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_23852\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Year        Pr       Mil       Tax       MPG       Eng
# Year  1.000000  0.623756 -0.774507  0.025200 -0.071762 -0.026221
# Pr    0.623756  1.000000 -0.605490  0.263484 -0.204882  0.460249
# Mil  -0.774507 -0.605490  1.000000 -0.170846  0.118677 -0.002670
# Tax   0.025200  0.263484 -0.170846  1.000000 -0.351798  0.429538
# MPG  -0.071762 -0.204882  0.118677 -0.351798  1.000000 -0.399887
# Eng  -0.026221  0.460249 -0.002670  0.429538 -0.399887  1.000000

# %%
df.Year.unique().sum()
# Out:
# 50200

# %%
data = {'A': [2,6,8,1], 'B': [4,6,1,4]}
data = pd.DataFrame(data)
data
# Out:
#    A  B
# 0  2  4
# 1  6  6
# 2  8  1
# 3  1  4

# %%
data.cumsum()
# Out:
#     A   B
# 0   2   4
# 1   8  10
# 2  16  11
# 3  17  15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Model   10781 non-null  object
#  1   Year    10781 non-null  int64
#  2   Pr      10781 non-null  int64
#  3   Trans   10775 non-null  object
#  4   Mil     10775 non-null  float64
#  5   FT      10781 non-null  object
#  6   Tax     10781 non-null  int64
#  7   MPG     10781 non-null  float64
#  8   Eng     10774 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 758.2+ KB

# %%
 df.astype(str)
# Out:
#            Model  Year     Pr      Trans      Mil      FT  Tax   MPG  Eng
# 0       5 Series  2014  11200  Automatic  67068.0  Diesel  125  57.6  2.0
# 1       6 Series  2018  27000  Automatic  14827.0  Petrol  145  42.8  2.0
# 2       5 Series  2016  16000  Automatic      nan  Diesel  160  51.4  3.0
# 3       1 Series  2017  12750        nan  26676.0  Diesel  145  72.4  1.5
# 4       7 Series  2014  14500  Automatic  39554.0  Diesel  160  50.4  nan
# ...          ...   ...    ...        ...      ...     ...  ...   ...  ...
# 10776         X3  2016  19000  Automatic  40818.0  Diesel  150  54.3  2.0
# 10777   5 Series  2016  14600  Automatic  42947.0  Diesel  125  60.1  2.0
# 10778   3 Series  2017  13100     Manual  25468.0  Petrol  200  42.8  2.0
# 10779   1 Series  2014   9930  Automatic  45000.0  Diesel   30  64.2  2.0
# 10780         X1  2017  15981  Automatic  59432.0  Diesel  125  57.6  2.0
#
# [10781 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Model   10781 non-null  object
#  1   Year    10781 non-null  int64
#  2   Pr      10781 non-null  int64
#  3   Trans   10775 non-null  object
#  4   Mil     10775 non-null  float64
#  5   FT      10781 non-null  object
#  6   Tax     10781 non-null  int64
#  7   MPG     10781 non-null  float64
#  8   Eng     10774 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 758.2+ KB

# %%
df.convert_dtypes()
# Out:
#            Model  Year     Pr      Trans    Mil      FT  Tax   MPG   Eng
# 0       5 Series  2014  11200  Automatic  67068  Diesel  125  57.6   2.0
# 1       6 Series  2018  27000  Automatic  14827  Petrol  145  42.8   2.0
# 2       5 Series  2016  16000  Automatic   <NA>  Diesel  160  51.4   3.0
# 3       1 Series  2017  12750       <NA>  26676  Diesel  145  72.4   1.5
# 4       7 Series  2014  14500  Automatic  39554  Diesel  160  50.4  <NA>
# ...          ...   ...    ...        ...    ...     ...  ...   ...   ...
# 10776         X3  2016  19000  Automatic  40818  Diesel  150  54.3   2.0
# 10777   5 Series  2016  14600  Automatic  42947  Diesel  125  60.1   2.0
# 10778   3 Series  2017  13100     Manual  25468  Petrol  200  42.8   2.0
# 10779   1 Series  2014   9930  Automatic  45000  Diesel   30  64.2   2.0
# 10780         X1  2017  15981  Automatic  59432  Diesel  125  57.6   2.0
#
# [10781 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Model   10781 non-null  object
#  1   Year    10781 non-null  int64
#  2   Pr      10781 non-null  int64
#  3   Trans   10775 non-null  object
#  4   Mil     10775 non-null  float64
#  5   FT      10781 non-null  object
#  6   Tax     10781 non-null  int64
#  7   MPG     10781 non-null  float64
#  8   Eng     10774 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 758.2+ KB

# %%
df['Model'].dtype = int
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5933, in NDFrame.__setattr__(self, name, value)
#    5932     else:
# -> 5933         object.__setattr__(self, name, value)
#    5934 except (AttributeError, TypeError):
#
# AttributeError: property 'dtype' of 'Series' object has no setter
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In [124], line 1
# ----> 1 df['Model'].dtype = int
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5943, in NDFrame.__setattr__(self, name, value)
#    5935 if isinstance(self, ABCDataFrame) and (is_list_like(value)):
#    5936     warnings.warn(
#    5937         "Pandas doesn't allow columns to be "
# ...

# %%
# https://stackoverflow.com/questions/15891038/change-column-type-in-pandas#:~:text=The%20best%20way%20to%20convert,floating%2Dpoint%20numbers%20as%20appropriate.

# %%
# https://www.educative.io/answers/what-is-loc-in-pandas
# about loc
