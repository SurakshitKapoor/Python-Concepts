# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Shivam\Desktop\Python\bmw csv.csv")

# %%
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic  67068.0   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic  14827.0   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic      NaN   Diesel  160  51.4
# 3       1 Series  2017  12750          NaN  26676.0   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic  39554.0   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic  40818.0   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic  42947.0   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual  25468.0   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic  45000.0   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic  59432.0   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
plt.figure(figsize = (20,8))
plt.plot(df['model'], df['tax'])

# %%
plt.figure(figsize = (20,8))
plt.hist(df['model'])
# Out:
# (array([3133., 1335., 1546., 3090.,  847.,  413.,  253.,   84.,   38.,
#           42.]),
#  array([ 0. ,  2.3,  4.6,  6.9,  9.2, 11.5, 13.8, 16.1, 18.4, 20.7, 23. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize = (20,8))
plt.scatter(df['model'], df['year'])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
plt.figure(figsize = (20,8))
plt.bar(df['model'], df['year'])
# Out:
# <BarContainer object of 10781 artists>

# %%
#seaborn

# %%
plt.figure(figsize = (20,8))
plt.title("Counts of Models", fontsize = 24, fontweight = 'bold')
gr = sns.countplot(x = 'model', data = df)

# %%
plt.figure(figsize = (20,8))
sns.lineplot(x = df['model'], y = df['year'] , data = df)

# %%
df.plot.pie(y = 'year')

# %%
# plt.pie(df['year'])

# %%
df.plot.hist(df['model'])

# %%
plt.plot(df['model'], y = ['year'])

# %%
pandas viz.
maltplotlib.pyplot viz
seaborn viz

# %% [markdown]
# # graph using pd, plt, sns

# %%
df_bat = pd.read_csv("C:\\Users\\Shivam\\Desktop\\Python\\batting.csv")
# df_bat = pd.read_csv(r"C:\Users\Shivam\Desktop\Python\batting.csv") - same

# %%
df_bat
# Out:
#                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#                                dismissal  runs  balls  4s  6s      SR  \
# ...

# %%
b = df_bat['balls']

# %% [markdown]
# **using pd**

# %%
b.plot.bar()
# Out:
# <AxesSubplot: >

# %%
b.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
plt.figure(figsize = (20,8))
b.plot.pie()
# Out:
# <AxesSubplot: ylabel='balls'>

# %%
b.plot.line()
# Out:
# <AxesSubplot: >

# %% [markdown]
# **using plt**

# %%
plt.plot(b)

# %%
r = df_bat['runs']

# %% [markdown]
# **using sns**

# %%
sns.lineplot(x = b, y = r, data = df_bat)
plt.title("Runs Vs balls")
# Out:
# Text(0.5, 1.0, 'Runs Vs balls')

# %%
plt.figure(figsize = (20,8))
sns.countplot(x = b)
# Out:
# <AxesSubplot: xlabel='balls', ylabel='count'>

# %%
sns.scatterplot(x = b, y = r, data = df_bat)
# Out:
# <AxesSubplot: xlabel='balls', ylabel='runs'>
